# %% [markdown]
# # <font color='blue'>Data Science Academy - Machine Learning</font>
#
# # <font color='blue'>Capítulo 6 - Otimização dos Parâmetros com Randomized Search</font>

# %% [markdown]
# ## Extremely Randomized Forest

# %%
# Abrir um prompt ou terminal e executar o comando abaixo (responder yes quando solicitado). Reiniciar o Kernel do Jupyter Notebook
# conda update scikit-learn

# %%
import sklearn as sl
sl.__version__
# Out:
# '0.19.1'

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
from sklearn.preprocessing import scale
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# Carrega o dataset
data = pd.read_excel('credit.xls', skiprows = 1)

# Variável target
target = 'default payment next month'
y = np.asarray(data[target])

# Variáveis preditoras
features = data.columns.drop(['ID', target])
X = np.asarray(data[features])

# Dataset de treino e de teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 99)

# Classificador
clf = ExtraTreesClassifier(n_estimators = 500, random_state = 99)

# Modelo
clf.fit(X_train, y_train)

# Score
scores = cross_val_score(clf, X_train, y_train, cv = 3, scoring = 'accuracy', n_jobs = -1)

# Imprimindo o resultado
print ("ExtraTreesClassifier -> Acurácia: Média = %0.3f Desvio Padrão = %0.3f" % (np.mean(scores), np.std(scores)))

# Fazendo previsões
y_pred = clf.predict(X_test)

# Confusion Matrix
confusionMatrix = confusion_matrix(y_test, y_pred)
print (confusionMatrix)

# Acurácia
accuracy_score(y_test, y_pred)
# Out:
# ExtraTreesClassifier -> Acurácia: Média = 0.812 Desvio Padrão = 0.002
# [[6532  446]
#  [1273  749]]
# 0.809

# %% [markdown]
# ## Otimização dos Parâmetros com Randomized Search

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html

# %% [markdown]
# O Randomized Search gera amostras dos parâmetros dos algoritmos a partir de uma distribuição randômica uniforme para um número fixo de interações. Um modelo é construído e testado para cada combinação de parâmetros.

# %%
# Import
from sklearn.model_selection import RandomizedSearchCV

# %%
# Definição dos parâmetros
param_dist = {"max_depth": [1, 3, 7, 8, 12, None],
              "max_features": [8, 9, 10, 11, 16, 22],
              "min_samples_split": [8, 10, 11, 14, 16, 19],
              "min_samples_leaf": [1, 2, 3, 4, 5, 6, 7],
              "bootstrap": [True, False]}

# Para o classificador criado na célula anterior, testamos diferentes combinações de parâmetros
rsearch = RandomizedSearchCV(clf, param_distributions = param_dist, n_iter = 25,return_train_score=True)  

# Aplicando o resultado ao conjunto de dados de treino e obtendo o score
rsearch.fit(X_train,y_train)

### ALTERACAO PARA cv_results_
rsearch.cv_results_

# Imprimindo o melhor estimador
bestclf = rsearch.best_estimator_
print (bestclf)

# Aplicando o melhor estimador para realizar as previsões
y_pred = bestclf.predict(X_test)

# Confusion Matrix
confusionMatrix = confusion_matrix(y_test, y_pred)
print(confusionMatrix)

# Acurácia
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# ExtraTreesClassifier(bootstrap=True, class_weight=None, criterion='gini',
#            max_depth=7, max_features=16, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=5, min_samples_split=10,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#            oob_score=False, random_state=99, verbose=0, warm_start=False)
# [[6648  330]
#  [1282  740]]
# 0.8208888888888889

# %%
# Obtendo o grid com todas as combinações de parâmetros
rsearch.cv_results_
# Out:
# {'mean_fit_time': array([3.29193751, 2.85922114, 3.3010966 , 2.47661034, 3.2055877 ,
#         5.36168869, 3.06354372, 1.59435805, 9.18926835, 7.60961016,
#         4.37964145, 2.38128471, 6.71382157, 8.9254969 , 7.27037541,
#         1.37884164, 1.36238233, 1.50590301, 7.16070239, 4.52097273,
#         3.70752239, 1.40684374, 3.43521261, 2.40370456, 1.07045563]),
#  'std_fit_time': array([0.06247686, 0.03698078, 0.03636771, 0.01724194, 0.03250518,
#         0.03238586, 0.03240895, 0.02628069, 0.37217858, 0.36370598,
#         0.1034462 , 0.04075574, 0.415562  , 0.77506886, 0.11254875,
#         0.00327235, 0.0096132 , 0.05576319, 0.09591034, 0.0965629 ,
#         0.09589124, 0.024081  , 0.04928218, 0.06192724, 0.01853477]),
#  'mean_score_time': array([0.3298227 , 0.24607197, 0.22944768, 0.22220858, 0.24171853,
#         0.56361159, 0.22161396, 0.15408762, 0.34588925, 0.58042844,
#         0.33878636, 0.21993033, 0.36393404, 0.48102037, 0.54222409,
#         0.15266681, 0.15344659, 0.15151008, 0.51952426, 0.24974569,
#         0.25627033, 0.13189212, 0.33842921, 0.24552083, 0.12980199]),
#  'std_score_time': array([0.00206092, 0.00758593, 0.00301368, 0.00071426, 0.00136955,
#         0.01563153, 0.00286717, 0.00245317, 0.00827419, 0.04220909,
#         0.00265244, 0.00352115, 0.03373976, 0.0182533 , 0.00663385,
#         0.00156048, 0.00127334, 0.00108948, 0.03443353, 0.00360859,
#         0.01990255, 0.00164292, 0.0058773 , 0.00109693, 0.00132216]),
#  'param_min_samples_split': masked_array(data=[19, 10, 10, 14, 19, 10, 19, 19, 14, 10, 16, 19, 19, 16,
#                     16, 8, 19, 14, 10, 11, 19, 19, 16, 10, 16],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[7, 1, 5, 4, 2, 1, 2, 2, 5, 6, 4, 6, 2, 7, 4, 6, 3, 5,
#                     4, 5, 2, 4, 3, 6, 5],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[9, 11, 16, 10, 9, 8, 10, 11, 22, 10, 8, 10, 22, 22, 10,
#                     8, 8, 10, 16, 22, 11, 22, 9, 8, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[12, 8, 7, 7, 8, None, 7, 3, 12, None, 12, 7, 12, None,
#                     None, 3, 3, 3, None, 8, 8, 1, 12, 8, 1],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_bootstrap': masked_array(data=[True, True, True, True, False, True, False, True,
#                     False, False, False, True, True, True, False, True,
#                     True, True, True, True, False, False, True, True,
#                     False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'min_samples_split': 19,
#    'min_samples_leaf': 7,
#    'max_features': 9,
#    'max_depth': 12,
#    'bootstrap': True},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 11,
#    'max_depth': 8,
#    'bootstrap': True},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 5,
#    'max_features': 16,
#    'max_depth': 7,
#    'bootstrap': True},
#   {'min_samples_split': 14,
#    'min_samples_leaf': 4,
#    'max_features': 10,
#    'max_depth': 7,
#    'bootstrap': True},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 2,
#    'max_features': 9,
#    'max_depth': 8,
#    'bootstrap': False},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 8,
#    'max_depth': None,
#    'bootstrap': True},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 2,
#    'max_features': 10,
#    'max_depth': 7,
#    'bootstrap': False},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 2,
#    'max_features': 11,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 14,
#    'min_samples_leaf': 5,
#    'max_features': 22,
#    'max_depth': 12,
#    'bootstrap': False},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 6,
#    'max_features': 10,
#    'max_depth': None,
#    'bootstrap': False},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 4,
#    'max_features': 8,
#    'max_depth': 12,
#    'bootstrap': False},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 6,
#    'max_features': 10,
#    'max_depth': 7,
#    'bootstrap': True},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 2,
#    'max_features': 22,
#    'max_depth': 12,
#    'bootstrap': True},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 7,
#    'max_features': 22,
#    'max_depth': None,
#    'bootstrap': True},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 4,
#    'max_features': 10,
#    'max_depth': None,
#    'bootstrap': False},
#   {'min_samples_split': 8,
#    'min_samples_leaf': 6,
#    'max_features': 8,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 3,
#    'max_features': 8,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 14,
#    'min_samples_leaf': 5,
#    'max_features': 10,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 16,
#    'max_depth': None,
#    'bootstrap': True},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 5,
#    'max_features': 22,
#    'max_depth': 8,
#    'bootstrap': True},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 2,
#    'max_features': 11,
#    'max_depth': 8,
#    'bootstrap': False},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 4,
#    'max_features': 22,
#    'max_depth': 1,
#    'bootstrap': False},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 3,
#    'max_features': 9,
#    'max_depth': 12,
#    'bootstrap': True},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 6,
#    'max_features': 8,
#    'max_depth': 8,
#    'bootstrap': True},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 5,
#    'max_features': 10,
#    'max_depth': 1,
#    'bootstrap': False}],
#  'split0_test_score': array([0.82142857, 0.82257143, 0.823     , 0.81985714, 0.81828571,
#         0.82128571, 0.821     , 0.80171429, 0.82257143, 0.82142857,
#         0.82185714, 0.82142857, 0.82314286, 0.82214286, 0.822     ,
#         0.799     , 0.79928571, 0.80085714, 0.82085714, 0.824     ,
#         0.82242857, 0.78385714, 0.82214286, 0.82014286, 0.78028571]),
#  'split1_test_score': array([0.819     , 0.819     , 0.82042857, 0.81657143, 0.81714286,
#         0.81771429, 0.81842857, 0.80285714, 0.81814286, 0.81785714,
#         0.818     , 0.81814286, 0.818     , 0.81757143, 0.81728571,
#         0.80085714, 0.80042857, 0.80185714, 0.81628571, 0.81871429,
#         0.81957143, 0.784     , 0.81814286, 0.81657143, 0.78028571]),
#  'split2_test_score': array([0.81857143, 0.81814286, 0.81928571, 0.81828571, 0.81685714,
#         0.81571429, 0.81771429, 0.80157143, 0.818     , 0.81357143,
#         0.81757143, 0.81671429, 0.818     , 0.81557143, 0.815     ,
#         0.79828571, 0.79842857, 0.79985714, 0.81514286, 0.81971429,
#         0.81885714, 0.78314286, 0.81742857, 0.81542857, 0.78028571]),
#  'mean_test_score': array([0.81966667, 0.81990476, 0.82090476, 0.8182381 , 0.81742857,
#         0.8182381 , 0.81904762, 0.80204762, 0.81957143, 0.81761905,
#         0.81914286, 0.8187619 , 0.81971429, 0.81842857, 0.81809524,
#         0.79938095, 0.79938095, 0.80085714, 0.81742857, 0.82080952,
#         0.82028571, 0.78366667, 0.8192381 , 0.81738095, 0.78028571]),
#  'std_test_score': array([0.00125808, 0.00191781, 0.00155329, 0.00134181, 0.00061721,
#         0.00230449, 0.001411  , 0.00057538, 0.00212212, 0.00321208,
#         0.00192725, 0.00197375, 0.00242437, 0.00275039, 0.0029145 ,
#         0.00108379, 0.00081927, 0.0008165 , 0.00246885, 0.00229265,
#         0.00154303, 0.00037495, 0.00207457, 0.00200792, 0.        ]),
#  'rank_test_score': array([ 6,  4,  1, 13, 17, 13, 10, 20,  7, 16,  9, 11,  5, 12, 15, 22, 22,
#         21, 17,  2,  3, 24,  8, 19, 25], dtype=int32),
#  'split0_train_score': array([0.83135714, 0.83135714, 0.82742857, 0.8235    , 0.82614286,
#         0.89285714, 0.82535714, 0.80157143, 0.85707143, 0.86142857,
#         0.84157143, 0.824     , 0.84878571, 0.84835714, 0.86835714,
#         0.79914286, 0.79914286, 0.80092857, 0.86571429, 0.83185714,
#         0.83057143, 0.78271429, 0.83957143, 0.8245    , 0.78028571]),
#  'split1_train_score': array([0.8345    , 0.83428571, 0.8285    , 0.82714286, 0.83228571,
#         0.89164286, 0.82928571, 0.80214286, 0.85492857, 0.86035714,
#         0.84457143, 0.82685714, 0.847     , 0.84585714, 0.86635714,
#         0.79978571, 0.79964286, 0.8005    , 0.86564286, 0.83414286,
#         0.8325    , 0.785     , 0.84171429, 0.82735714, 0.78028571]),
#  'split2_train_score': array([0.83264286, 0.83071429, 0.828     , 0.82707143, 0.83028571,
#         0.89164286, 0.82742857, 0.80421429, 0.85835714, 0.86214286,
#         0.84221429, 0.82528571, 0.84928571, 0.84864286, 0.86814286,
#         0.80071429, 0.80071429, 0.8025    , 0.8685    , 0.83207143,
#         0.83007143, 0.78371429, 0.83978571, 0.82557143, 0.78028571]),
#  'mean_train_score': array([0.83283333, 0.83211905, 0.82797619, 0.82590476, 0.82957143,
#         0.89204762, 0.82735714, 0.80264286, 0.85678571, 0.86130952,
#         0.84278571, 0.82538095, 0.84835714, 0.84761905, 0.86761905,
#         0.79988095, 0.79983333, 0.80130952, 0.86661905, 0.83269048,
#         0.83104762, 0.78380952, 0.84035714, 0.82580952, 0.78028571]),
#  'std_train_score': array([0.00129012, 0.00155438, 0.00043773, 0.00170067, 0.00255817,
#         0.00057242, 0.00160463, 0.00113539, 0.00141421, 0.00073386,
#         0.00128968, 0.00116837, 0.00098111, 0.0012513 , 0.00089658,
#         0.00064506, 0.00065552, 0.00085978, 0.00133035, 0.00103071,
#         0.00104708, 0.00093557, 0.00096362, 0.00117851, 0.        ])}

# %% [markdown]
# ## Grid Search x Randomized Search para Estimação dos Hiperparâmetros

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html

# %% [markdown]
# O Grid Search realiza metodicamente combinações entre todos os parâmetros do algoritmo, criando um grid.

# %%
import numpy as np
from time import time
from scipy.stats import randint as sp_randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.datasets import load_digits

# Obtém o dataset
digits = load_digits()
X, y = digits.data, digits.target

# Construindo o classificador
clf = RandomForestClassifier(n_estimators = 20)

# %%
# Randomized Search

# Valores dos parâmetros que serão testados
param_dist = {"max_depth": [3, None],
              "max_features": sp_randint(1, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# Executando o Randomized Search
n_iter_search = 20
random_search = RandomizedSearchCV(clf, 
                                   param_distributions = param_dist, 
                                   n_iter = n_iter_search,
                                   return_train_score=True)

start = time()
random_search.fit(X, y)
print("RandomizedSearchCV executou em %.2f segundos para %d candidatos a parâmetros do modelo." 
      % ((time() - start), n_iter_search))

# Imprime as combinações dos parâmetros e susas respectivas médias de acurácia
random_search.cv_results_
# Out:
# RandomizedSearchCV executou em 2.41 segundos para 20 candidatos a parâmetros do modelo.
# {'mean_fit_time': array([0.025997  , 0.01895261, 0.04454859, 0.03694304, 0.02779222,
#         0.04843569, 0.02788146, 0.02397148, 0.04269894, 0.02700305,
#         0.02497411, 0.02621333, 0.05310337, 0.03996555, 0.01983738,
#         0.02846948, 0.02138734, 0.02985454, 0.03924926, 0.03750134]),
#  'std_fit_time': array([1.85677947e-03, 2.09600534e-05, 3.80369976e-03, 1.10094156e-03,
#         4.87736627e-04, 5.67221634e-04, 1.33355995e-03, 1.53452700e-03,
#         4.53628145e-04, 3.87492077e-04, 6.64855448e-04, 2.12620216e-04,
#         9.07902297e-04, 5.77102479e-04, 6.23293231e-05, 2.46241523e-04,
#         6.79514784e-04, 6.39299966e-04, 4.74018841e-04, 2.61478776e-04]),
#  'mean_score_time': array([0.00212097, 0.0021441 , 0.00305549, 0.00272965, 0.00273379,
#         0.00263031, 0.00293668, 0.0023191 , 0.00292031, 0.0023044 ,
#         0.00233976, 0.00214895, 0.00267529, 0.00294749, 0.00199493,
#         0.00222349, 0.00210849, 0.00270677, 0.0029285 , 0.00271932]),
#  'std_score_time': array([6.99362068e-05, 1.23728140e-04, 2.45087367e-04, 2.13016649e-04,
#         9.10647315e-05, 2.16652869e-04, 2.97941599e-04, 2.05319883e-04,
#         3.21657993e-05, 2.08314208e-04, 1.45691028e-04, 1.10567514e-04,
#         1.18438134e-04, 3.09409410e-04, 1.95147545e-05, 4.31653968e-05,
#         6.33734144e-05, 1.99641740e-04, 6.96160477e-05, 2.59365982e-04]),
#  'param_bootstrap': masked_array(data=[False, False, False, False, False, False, True, True,
#                     False, False, True, False, False, True, True, False,
#                     True, True, True, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['gini', 'entropy', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'gini', 'entropy', 'gini',
#                     'gini', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'gini', 'entropy', 'gini'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[3, 3, None, None, None, None, 3, 3, None, 3, 3, 3,
#                     None, None, 3, 3, 3, None, None, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[6, 1, 7, 6, 2, 10, 3, 3, 5, 8, 6, 7, 10, 6, 1, 7, 2, 4,
#                     5, 6],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[10, 3, 6, 10, 3, 7, 4, 2, 1, 5, 6, 1, 3, 3, 8, 7, 4, 5,
#                     1, 7],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 6,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 7,
#    'min_samples_leaf': 6},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 6,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 2,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 7},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 4},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 2},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 5,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 8,
#    'min_samples_leaf': 5},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 6,
#    'min_samples_leaf': 6},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 7,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 6,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 8},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 7,
#    'min_samples_leaf': 7},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 2,
#    'min_samples_leaf': 4},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 4,
#    'min_samples_leaf': 5},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 5,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 6,
#    'min_samples_leaf': 7}],
#  'split0_test_score': array([0.80232558, 0.80564784, 0.91860465, 0.8986711 , 0.91694352,
#         0.910299  , 0.84219269, 0.83388704, 0.92358804, 0.82890365,
#         0.80066445, 0.81893688, 0.91860465, 0.910299  , 0.74750831,
#         0.80564784, 0.78903654, 0.90531561, 0.90863787, 0.91860465]),
#  'split1_test_score': array([0.82136895, 0.79632721, 0.93823038, 0.91819699, 0.9148581 ,
#         0.93322204, 0.77963272, 0.81469115, 0.93989983, 0.80133556,
#         0.82136895, 0.83973289, 0.94991653, 0.92654424, 0.75626043,
#         0.8196995 , 0.84140234, 0.9148581 , 0.93155259, 0.91986644]),
#  'split2_test_score': array([0.82214765, 0.74328859, 0.90436242, 0.90268456, 0.91107383,
#         0.89597315, 0.81543624, 0.79194631, 0.93120805, 0.79865772,
#         0.78020134, 0.81208054, 0.92281879, 0.90604027, 0.75503356,
#         0.77348993, 0.81208054, 0.89765101, 0.89597315, 0.90268456]),
#  'mean_test_score': array([0.81524763, 0.78185865, 0.92042293, 0.90651085, 0.91430161,
#         0.91318865, 0.81246522, 0.81357819, 0.93155259, 0.8096828 ,
#         0.80077908, 0.82359488, 0.93043962, 0.91430161, 0.75292154,
#         0.79966611, 0.81413467, 0.90595437, 0.91207568, 0.91374513]),
#  'std_test_score': array([0.00917711, 0.02743658, 0.01386935, 0.00842422, 0.00242836,
#         0.01532555, 0.02565739, 0.0171401 , 0.00667199, 0.0136859 ,
#         0.01678569, 0.01174957, 0.01387929, 0.0088297 , 0.00387455,
#         0.0193137 , 0.02145379, 0.00703057, 0.01471077, 0.00780869]),
#  'rank_test_score': array([12, 19,  3,  9,  4,  7, 15, 14,  1, 16, 17, 11,  2,  4, 20, 18, 13,
#         10,  8,  6], dtype=int32),
#  'split0_train_score': array([0.88200837, 0.86610879, 0.99665272, 0.98242678, 0.99832636,
#         0.99665272, 0.86945607, 0.89205021, 1.        , 0.88953975,
#         0.88619247, 0.87698745, 1.        , 0.99832636, 0.83682008,
#         0.85104603, 0.82761506, 0.98828452, 1.        , 0.99665272]),
#  'split1_train_score': array([0.85392321, 0.82470785, 0.9966611 , 0.99081803, 0.99916528,
#         0.9933222 , 0.85475793, 0.88647746, 1.        , 0.86227045,
#         0.88480801, 0.87646077, 1.        , 0.99833055, 0.84474124,
#         0.86894825, 0.87979967, 0.98163606, 1.        , 0.9933222 ]),
#  'split2_train_score': array([0.88259784, 0.80682764, 0.99833472, 0.98751041, 0.99916736,
#         0.99833472, 0.88925895, 0.87926728, 1.        , 0.89425479,
#         0.86178185, 0.85928393, 1.        , 0.99916736, 0.80266445,
#         0.8734388 , 0.877602  , 0.98751041, 1.        , 0.99333888]),
#  'mean_train_score': array([0.87284314, 0.83254809, 0.99721618, 0.98691841, 0.99888633,
#         0.99610321, 0.87115765, 0.88593165, 1.        , 0.88202166,
#         0.87759411, 0.87091072, 1.        , 0.99860809, 0.82807526,
#         0.86447769, 0.86167224, 0.98581033, 1.        , 0.99443794]),
#  'std_train_score': array([0.01338058, 0.02482828, 0.00079093, 0.0034512 , 0.00039596,
#         0.00208291, 0.01413628, 0.00523286, 0.        , 0.01409824,
#         0.01119523, 0.00822419, 0.        , 0.00039547, 0.01825684,
#         0.00967293, 0.02409877, 0.00296852, 0.        , 0.0015661 ])}

# %%
# Grid Search

# Usando um grid completo de todos os parâmetros
param_grid = {"max_depth": [3, None],
              "max_features": [1, 3, 10],
              "min_samples_leaf": [1, 3, 10],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# Executando o Grid Search
grid_search = GridSearchCV(clf, param_grid = param_grid,return_train_score=True)
start = time()
grid_search.fit(X, y)

print("GridSearchCV executou em %.2f segundos para todas as combinações de candidatos a parâmetros do modelo."
      % (time() - start))
grid_search.cv_results_
# Out:
# GridSearchCV executou em 8.12 segundos para todas as combinações de candidatos a parâmetros do modelo.
# {'mean_fit_time': array([0.02213097, 0.02012539, 0.01995786, 0.02182643, 0.02129404,
#         0.02104203, 0.02608569, 0.02680564, 0.02644976, 0.02633532,
#         0.02449195, 0.02380371, 0.03284423, 0.02901332, 0.02707124,
#         0.04441253, 0.04130101, 0.03762666, 0.02146371, 0.02194699,
#         0.01996875, 0.02333681, 0.02206421, 0.02241365, 0.02925666,
#         0.02901014, 0.02981242, 0.03129538, 0.02481103, 0.02272852,
#         0.0363876 , 0.0318466 , 0.02889625, 0.05388204, 0.04913823,
#         0.04254039, 0.01939599, 0.01916567, 0.0191075 , 0.0217607 ,
#         0.02163339, 0.02203409, 0.02977689, 0.03015606, 0.03008763,
#         0.02986264, 0.02491315, 0.02156274, 0.03587437, 0.033132  ,
#         0.02908405, 0.05806271, 0.06475592, 0.04742972, 0.01979065,
#         0.01940823, 0.01972707, 0.02311095, 0.022753  , 0.02304657,
#         0.03239171, 0.03270674, 0.03212253, 0.03470929, 0.02644038,
#         0.02243884, 0.04171546, 0.03639539, 0.03174829, 0.06781006,
#         0.06177402, 0.05251861]),
#  'std_fit_time': array([4.27159916e-04, 2.33397379e-04, 4.86611106e-04, 2.90528232e-04,
#         4.35418968e-04, 2.35294242e-04, 6.33384861e-04, 5.86239338e-04,
#         3.41580767e-04, 1.18160357e-03, 1.04929112e-03, 2.05904627e-03,
#         1.15775174e-03, 4.53965684e-04, 9.06013773e-04, 4.06171519e-04,
#         2.46489607e-04, 1.04766959e-03, 1.27090328e-03, 1.98641643e-03,
#         8.59207789e-04, 4.80651790e-04, 2.79360859e-04, 5.24490975e-04,
#         5.77719337e-04, 2.06999173e-04, 8.55434019e-04, 5.02221944e-05,
#         4.50509723e-04, 4.69306946e-04, 5.00376411e-04, 8.05131066e-05,
#         6.83044925e-04, 3.58484954e-04, 3.23455925e-04, 6.41856390e-05,
#         1.03975712e-04, 4.28690764e-04, 1.92201690e-04, 2.73676560e-04,
#         4.04641261e-04, 5.53356265e-04, 2.48557464e-04, 7.50334477e-04,
#         3.98061570e-04, 8.91999093e-04, 3.02776472e-04, 4.38451457e-04,
#         3.35172826e-04, 4.34677473e-04, 5.80327745e-04, 7.73170961e-04,
#         3.80237862e-03, 7.38292952e-04, 8.31705868e-04, 2.71755837e-04,
#         4.76726532e-04, 2.43452131e-04, 2.68990543e-04, 7.14182375e-04,
#         5.21771360e-04, 2.15103774e-04, 6.04869277e-04, 7.08125933e-04,
#         2.91600900e-04, 1.09244863e-04, 6.04980065e-05, 2.70806449e-04,
#         1.56222074e-03, 2.66948827e-04, 8.84892882e-04, 5.19908035e-04]),
#  'mean_score_time': array([0.00249314, 0.0023249 , 0.00196552, 0.00241137, 0.00218399,
#         2.23138477e-04, 2.43018623e-04, 2.13040605e-04, 8.41286194e-05,
#         2.12761655e-04, 1.30625099e-04, 1.89991768e-04, 1.62159808e-04,
#         3.80611713e-04, 3.00669955e-04, 1.52066328e-04, 7.79450912e-05,
#         1.62444703e-04, 1.19317694e-04, 1.63235938e-04, 4.51037711e-05,
#         4.77973590e-05, 4.31203757e-04, 8.73009273e-05, 1.47313273e-04]),
#  'param_bootstrap': masked_array(data=[True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[3, 3, 3, 3, 3, 3, 3, 3, 3, None, None, None, None,
#                     None, None, None, None, None, 3, 3, 3, 3, 3, 3, 3, 3,
#                     3, None, None, None, None, None, None, None, None,
#                     None, 3, 3, 3, 3, 3, 3, 3, 3, 3, None, None, None,
#                     None, None, None, None, None, None, 3, 3, 3, 3, 3, 3,
#                     3, 3, 3, None, None, None, None, None, None, None,
#                     None, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3, 10, 10,
#                     10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3, 10,
#                     10, 10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3,
#                     10, 10, 10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3,
#                     3, 3, 10, 10, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3,
#                     10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10,
#                     1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3,
#                     10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10,
#                     1, 3, 10, 1, 3, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10}],
#  'split0_test_score': array([0.70598007, 0.75581395, 0.75747508, 0.82890365, 0.82724252,
#         0.81893688, 0.81561462, 0.84053156, 0.79900332, 0.89700997,
#         0.89534884, 0.84883721, 0.92192691, 0.91860465, 0.90863787,
#         0.93023256, 0.89368771, 0.90033223, 0.76910299, 0.6910299 ,
#         0.75581395, 0.84053156, 0.83222591, 0.79734219, 0.80730897,
#         0.8255814 , 0.81063123, 0.89700997, 0.87043189, 0.84883721,
#         0.90697674, 0.91362126, 0.88704319, 0.91860465, 0.8820598 ,
#         0.89036545, 0.7807309 , 0.71594684, 0.77242525, 0.83554817,
#         0.82059801, 0.8255814 , 0.77574751, 0.77242525, 0.80398671,
#         0.91694352, 0.91196013, 0.8654485 , 0.92524917, 0.92192691,
#         0.90365449, 0.93189369, 0.910299  , 0.90863787, 0.79069767,
#         0.72923588, 0.74418605, 0.77574751, 0.81395349, 0.82225914,
#         0.82392027, 0.82225914, 0.78903654, 0.90531561, 0.8986711 ,
#         0.86378738, 0.92026578, 0.910299  , 0.91362126, 0.92026578,
#         0.90365449, 0.90199336]),
#  'split1_test_score': array([0.77796327, 0.76794658, 0.79131886, 0.77796327, 0.81135225,
#         0.76293823, 0.79632721, 0.81135225, 0.78297162, 0.9148581 ,
#         0.88313856, 0.82470785, 0.92320534, 0.91652755, 0.89148581,
#         0.94490818, 0.95659432, 0.89816361, 0.78130217, 0.80300501,
#         0.70283806, 0.83806344, 0.8130217 , 0.8163606 , 0.8163606 ,
#         0.8130217 , 0.79966611, 0.89649416, 0.87646077, 0.84474124,
#         0.91318865, 0.93155259, 0.87479132, 0.94156928, 0.91986644,
#         0.9081803 , 0.76794658, 0.74624374, 0.73789649, 0.81469115,
#         0.81469115, 0.79131886, 0.83138564, 0.79632721, 0.81803005,
#         0.90651085, 0.89649416, 0.87813022, 0.92487479, 0.94824708,
#         0.87979967, 0.94490818, 0.93989983, 0.91652755, 0.80133556,
#         0.00736586, 0.01551127, 0.01857281, 0.00421892, 0.01259586,
#         0.01037512, 0.00905584, 0.01417054, 0.00702003, 0.00861729,
#         0.00855889, 0.01552869, 0.01491493, 0.00212627, 0.02162386,
#         0.02632453, 0.01843998, 0.00474862, 0.00247899, 0.00686899,
#         0.01597874, 0.00448441, 0.0082694 , 0.00899903, 0.01152523,
#         0.01226361, 0.0204656 ]),
#  'rank_test_score': array([70, 66, 63, 57, 39, 55, 47, 41, 62, 22, 31, 34, 10, 16, 24,  4, 12,
#         27, 60, 72, 71, 36, 38, 49, 49, 52, 59, 25, 32, 37, 17, 10, 30,  6,
#         21, 23, 64, 68, 67, 41, 54, 43, 49, 61, 46, 14, 25, 33,  6,  3, 29,
#          1,  8, 17, 58, 69, 65, 53, 40, 44, 48, 45, 56, 19, 28, 35,  5, 13,
#         20,  1,  8, 14], dtype=int32),
#  'split0_train_score': array([0.79748954, 0.82677824, 0.8209205 , 0.85188285, 0.86443515,
#         0.88033473, 0.86192469, 0.87112971, 0.85355649, 1.        ,
#         0.98912134, 0.94142259, 1.        , 0.99832636, 0.96820084,
#         1.        , 0.99748954, 0.97405858, 0.841841  , 0.77740586,
#         0.84267782, 0.87280335, 0.86861925, 0.86945607, 0.88200837,
#         0.89205021, 0.88535565, 1.        , 0.98075314, 0.92635983,
#         1.        , 0.9958159 , 0.97154812, 1.        , 0.99832636,
#         0.98242678, 0.81171548, 0.82594142, 0.8376569 , 0.88953975,
#         0.89539749, 0.86276151, 0.84853556, 0.841841  , 0.85188285,
#         1.        , 0.99832636, 0.95313808, 1.        , 1.        ,
#         0.98410042, 1.        , 1.        , 0.98242678, 0.85690377,
#         0.8167364 , 0.81841004, 0.82259414, 0.84937238, 0.86778243,
#         0.86610879, 0.88368201, 0.841841  , 1.        , 0.99748954,
#         0.96066946, 1.        , 1.        , 0.98242678, 1.        ,
#         1.        , 0.9958159 ]),
#  'split1_train_score': array([0.81719533, 0.83555927, 0.82804674, 0.8639399 , 0.88480801,
#         0.85642738, 0.84307179, 0.85809683, 0.84808013, 1.        ,
#         0.98747913, 0.91903172, 1.        , 0.9933222 , 0.96911519,
#         1.        , 0.99749583, 0.96911519, 0.82888147, 0.84056761,
#         0.78964942, 0.88564274, 0.88397329, 0.89565943, 0.87646077,
#         0.88898164, 0.8706177 , 1.        , 0.98580968, 0.92821369,
#         1.        , 0.99582638, 0.96076795, 1.        , 0.99248748,
#         0.97579299, 0.83973289, 0.84223706, 0.82554257, 0.860601  ,
#         0.86644407, 0.86227045, 0.87813022, 0.88146912, 0.87228715,
#         1.        , 0.99749583, 0.96744574, 1.        , 1.        ,
#         0.97579299, 1.        , 1.        , 0.98914858, 0.82804674,
#         0.83555927, 0.80217028, 0.87979967, 0.87562604, 0.88397329,
#         0.86310518, 0.85893155, 0.8706177 , 1.        , 0.99916528,
#         0.95325543, 1.        , 1.        , 0.98330551, 1.        ,
#         1.        , 0.98998331]),
#  'split2_train_score': array([0.79933389, 0.84346378, 0.8692756 , 0.84929226, 0.87843464,
#         0.88343047, 0.87843464, 0.85179017, 0.83180683, 1.        ,
#         0.98417985, 0.9325562 , 1.        , 0.9958368 , 0.97751873,
#         1.        , 0.99916736, 0.97002498, 0.86677769, 0.73605329,
#         0.81765196, 0.8734388 , 0.88759367, 0.89841799, 0.87427144,
#         0.86677769, 0.86094921, 1.        , 0.98501249, 0.92006661,
#         1.        , 0.99750208, 0.96502914, 1.        , 0.99916736,
#         0.98334721, 0.86261449, 0.82764363, 0.82930891, 0.87593672,
#         0.86511241, 0.90424646, 0.85761865, 0.85845129, 0.89425479,
#         1.        , 0.99250624, 0.9641965 , 1.        , 1.        ,
#         0.98751041, 1.        , 1.        , 0.98834305, 0.877602  ,
#         0.85428809, 0.83846794, 0.89508743, 0.88925895, 0.87177352,
#         0.85928393, 0.87593672, 0.86511241, 1.        , 0.99750208,
#         0.95587011, 1.        , 1.        , 0.98917569, 1.        ,
#         1.        , 0.99167361]),
#  'mean_train_score': array([0.80467292, 0.8352671 , 0.83941428, 0.85503833, 0.8758926 ,
#         0.87339753, 0.8611437 , 0.8603389 , 0.84448115, 1.        ,
#         0.98692677, 0.93100351, 1.        , 0.99582846, 0.97161159,
#         1.        , 0.99805091, 0.97106625, 0.84583339, 0.78467559,
#         0.81665973, 0.87729496, 0.88006207, 0.88784449, 0.87758019,
#         0.88260318, 0.87230752, 1.        , 0.98385844, 0.92488004,
#         1.        , 0.99638145, 0.96578174, 1.        , 0.9966604 ,
#         0.98052233, 0.83802095, 0.8319407 , 0.83083613, 0.87535916,
#         0.87565132, 0.87642614, 0.86142814, 0.86058714, 0.87280826,
#         1.        , 0.99610948, 0.96159344, 1.        , 1.        ,
#         0.98246794, 1.        , 1.        , 0.98663947, 0.85418417,
#         0.83552792, 0.81968276, 0.86582708, 0.87141913, 0.87450975,
#         0.86283263, 0.87285009, 0.85919037, 1.        , 0.9980523 ,
#         0.95659833, 1.        , 1.        , 0.98496932, 1.        ,
#         1.        , 0.99249094]),
#  'std_train_score': array([0.00888664, 0.00681497, 0.02131462, 0.00638259, 0.00850921,
#         0.01206608, 0.01444738, 0.00805293, 0.00923675, 0.        ,
#         0.00205482, 0.00920674, 0.        , 0.00204295, 0.00419363,
#         0.        , 0.00078945, 0.00214825, 0.01572652, 0.04297633,
#         0.02166012, 0.00590847, 0.00822518, 0.01305126, 0.00325626,
#         0.01126022, 0.01003528, 0.        , 0.00221977, 0.00348674,
#         0.        , 0.00079242, 0.00443304, 0.        , 0.00297061,
#         0.00336519, 0.02081466, 0.00731371, 0.00506218, 0.01182125,
#         0.01397323, 0.01967296, 0.01237861, 0.01624845, 0.0173022 ,
#         0.        , 0.00257033, 0.00612423, 0.        , 0.        ,
#         0.00492092, 0.        , 0.        , 0.00299692, 0.02032204,
#         0.01533043, 0.01484576, 0.0312009 , 0.01655311, 0.00688724,
#         0.00279289, 0.01033737, 0.01247203, 0.        , 0.00078701,
#         0.00307025, 0.        , 0.        , 0.0029959 , 0.        ,
#         0.        , 0.00245028])}

# %% [markdown]
# ### Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
