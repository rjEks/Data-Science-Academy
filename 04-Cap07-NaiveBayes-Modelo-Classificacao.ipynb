# %% [markdown]
# # <font color='blue'>Data Science Academy - Machine Learning</font>
#
# # <font color='blue'>Capítulo 7 - Naive Bayes</font>

# %% [markdown]
# ### Construindo um Classificador Naive Bayes em Python

# %% [markdown]
# Estamos construindo um classificador Naive Bayes com BernoulliNB e MultinomialNB em Python. Não usaremos as funções do Scikit-learn.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.datasets import fetch_20newsgroups
import logging
import sys
from time import time
from math import *
from matplotlib import pyplot as pl
from matplotlib.backends.backend_pdf import PdfPages

# %%
class MyBernClassifier():
  
    def __init__(self, smooth = 1):
        self._smooth = smooth 
        self._feat_prob = []
        self._class_prob = []
        self._Ncls = []
        self._Nfeat = []

    def train(self, X, y):
        print ("Treinando Bernoulli NB...")
        count_each_class = {}
        feature_count = {}
        alpha = self._smooth 
        temp = []
        temp.append(np.unique(y))
        self._Ncls.append(temp[0].size) # Número total de classes
        self._Nfeat.append(X[0].size)  # Número total de features
        
        for i in range(y.size):
            if y[i] in feature_count:
                continue
            else:
                feature_count[y[i]] = [0 for w in range (X[i].size)]
                

        # Conta os atributos para cada classe através do treinamento ou 
        # conta a ocorrência de cada classe através do treinamento
        for i in range (y.size):
            if y[i] in count_each_class:
                count_each_class[y[i]] +=1
            else:
                count_each_class[y[i]] = 1
            for j in  range(X[i].size):
                    feature_count[y[i]][j] += X[i][j]
                    
        # Calcula probabilidades de classe e atributos para cada classe      
        for cls in feature_count:
            
            num = (self._smooth+count_each_class[cls])
            din = (y.size+(self._Ncls[0]*self._smooth))
            self._class_prob.append((num/float(din)))
            ar = np.array([])
            for j in  range(X[i].size):
                
                num = (feature_count[cls][j] + self._smooth)
                din = (count_each_class[cls]+(2*self._smooth))
                ar = np.append(ar,(num/float(din)))
            self._feat_prob.append(ar)
    

    def predict(self, X):
        
        print ("Fazendo Previsões com Bernoulli NB...")
        
        Y_predict = np.array([])

        for i in X:
            neg_log_prob = 0
            minimum_neg_log_prob = 999999999999999
            category = 0  
                
            for cls in range(self._Ncls[0]):
                neg_log_prob = -log(self._class_prob[cls])
                for j in  range(self._Nfeat[0]):  
                    if (i[j])==0:
                        neg_log_prob -= log(1-self._feat_prob[cls][j])
                    else:
                        neg_log_prob -= log(self._feat_prob[cls][j])
                        
                if minimum_neg_log_prob>neg_log_prob:
                    category=cls
                    minimum_neg_log_prob=neg_log_prob
            
            Y_predict=np.append(Y_predict,category)
         
        return Y_predict

# %%
class MyMultinomialBayesClassifier():
    
    def __init__(self, smooth = 1):
        self._smooth = smooth 
        self._feat_prob = []
        self._class_prob = []
        self._class_neg_prob = []
        self._Ncls = []
        self._Nfeat = []

    def train(self, X, y):
        print ("Treinando Multinomial NB...")
        
        count_each_class = {}
        feature_count = {}
      
        for i in range(y.size):
            if y[i] in feature_count:
                continue
            else:
                feature_count[y[i]] = [0 for w in range (X[i].size)]
                
        for i in range (y.size):
            if y[i] in count_each_class:
                count_each_class[y[i]] +=1
            else:
                count_each_class[y[i]] = 1
            for j in  range(X[i].size):
                    feature_count[y[i]][j] += X[i][j]
                
        alpha = self._smooth 
        temp = []
        temp.append(np.unique(y))
        self._Ncls.append(temp[0].size)
        self._Nfeat.append(X[0].size)  
        self._class_prob.append(count_each_class)
        self._feat_prob.append(feature_count)
        
        
    
    def predict(self, X):
        
        print ("Fazendo Previsões com Multinomial NB...")
        
        Y_predict = np.array([])
        
        # Calcula o total de classes para os dados de treino
        total_train_count = 0
        for key in self._class_prob[0]:
            total_train_count += self._class_prob[0][key]
        
        for i in X:
            neg_log_prob = 0
            minimum_neg_log_prob=999999999999999
            category = 0
            
            for cls in self._feat_prob[0]:
                Ny = sum(self._feat_prob[0][cls])
                neg_log_prob = -log((self._class_prob[0][cls]+1)/float(total_train_count+(self._Ncls[0]*self._smooth)))
                for j in  range(self._Nfeat[0]):  
                    if (i[j])==0:
                        continue    
                    for itere in range (i[j]):
                        num = (self._smooth+self._feat_prob[0][cls][j])
                        din = (Ny+(self._Nfeat[0]*self._smooth))
                        neg_log_prob -= log(num/float(din))
                        
                if minimum_neg_log_prob>neg_log_prob:
                    category=cls
                    minimum_neg_log_prob=neg_log_prob
            
            Y_predict=np.append(Y_predict,category)
         
        return Y_predict

# %%
# Define as classes que serão usadas no processo de classificação
categories = [
        'alt.atheism',
        'talk.religion.misc',
        'comp.graphics',
        'sci.space',
    ]
remove = ('headers', 'footers', 'quotes')

# %%
# Carrega os dados
data_train = fetch_20newsgroups(subset = 'train', categories = categories, shuffle = True, random_state = 42, remove = remove)
data_test = fetch_20newsgroups(subset = 'test', categories = categories, shuffle = True, random_state = 42, remove = remove)
print('Dados Carregados!')
# Out:
# Dados Carregados!

# %%
# Treino e Teste
y_train, y_test = data_train.target, data_test.target

# %%
print("Extraindo as features do dataset de treino usando o count vectorizer")
t0 = time()
# Out:
# Extraindo as features do dataset de treino usando o count vectorizer

# %%
# Binary = true for Bernoulli NB
vectorizer = CountVectorizer(stop_words = 'english', binary = True)
X_train = vectorizer.fit_transform(data_train.data).toarray()
X_test = vectorizer.transform(data_test.data).toarray()
feature_names = vectorizer.get_feature_names()

# %%
# For Bernoulli NB, Binary = true, train for one default smooth value alpha = 1

print ('-------------------------------------------------------------')
print ('Tempo esperado para execução do modelo Bernoulli NB é 180 seg')
ta = time()
alpha = 1
clf = MyBernClassifier(alpha)
clf.train(X_train,y_train)
y_pred = clf.predict(X_test)
tb = time()
print ("Para o modelo Bernoulli NB:  " +'alpha = %f, accuracy = %f' %(alpha, np.mean((y_test - y_pred)==0)))
print ("Tempo total para treinar e prever com o modelo Bernoulli: " + str(tb-ta))
print ('-------------------------------------------------------------')
# Out:
# -------------------------------------------------------------
# Tempo esperado para execução do modelo Bernoulli NB é 180 seg
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Para o modelo Bernoulli NB:  alpha = 1.000000, accuracy = 0.310421
# Tempo total para treinar e prever com o modelo Bernoulli: 138.72342777252197
# -------------------------------------------------------------

# %% [markdown]
# ### Esta célula pode levar horas para ser executada!

# %%
# Bernoulli Naive bayes: Alpha Vs accuracy
acc = []
alp = []

for alpha in [float(j) / 100 for j in range(1, 101, 1)]:
    print ('-----------------------------------------------------------------------------------------------------')
    ta = time()
    clf = MyBernClassifier(alpha)
    clf.train(X_train,y_train)
    y_pred = clf.predict(X_test)
    acc.append(np.mean((y_test-y_pred)==0))
    alp.append(alpha)
    tb = time()
    print ("Tempo de treinamento: " + str(tb-ta) + " acurácia, alpha is: " + str(np.mean((y_test-y_pred)==0)) +","+str(alpha))

# Plotting 
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 110.88921403884888 acurácia, alpha is: 0.3163340724316334,0.92
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 111.01002907752991 acurácia, alpha is: 0.3163340724316334,0.93
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 110.6109139919281 acurácia, alpha is: 0.3155949741315595,0.94
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 111.09419012069702 acurácia, alpha is: 0.31411677753141165,0.95
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 108.8912582397461 acurácia, alpha is: 0.31411677753141165,0.96
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 109.13447904586792 acurácia, alpha is: 0.31116038433111604,0.97
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 109.71083879470825 acurácia, alpha is: 0.31116038433111604,0.98
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 110.31188774108887 acurácia, alpha is: 0.31116038433111604,0.99
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 114.26641607284546 acurácia, alpha is: 0.31042128603104213,1.0
# Acurácia máxima do modelo Bernoulli NB is: 0.31929046563192903
# com valor correspondente para alpha de:       0.75

# %%
# Binary = false para Multinomial NB

print ("Extraindo dados com Binary = False para Multinomial NB")
vectorizer = CountVectorizer(stop_words = 'english', binary = False)
X_train = vectorizer.fit_transform(data_train.data).toarray()
X_test = vectorizer.transform(data_test.data).toarray()
feature_names = vectorizer.get_feature_names()

print ('Tempo total esperado para execução do Multinomial NB é 90 seg')
ta = time()
alpha = 1
clf1 = MyMultinomialBayesClassifier(alpha)
clf1.train(X_train,y_train)
y_pred = clf1.predict(X_test)

print ("Para modelo Multinomial NB:  " +'alpha = %f accuracy = %f' %(alpha, np.mean((y_test-y_pred)==0)))
tb = time()
print ("Tempo total para treinar e prever o modelo Multinomial: " + str(tb-ta))
print ('--------------------------------------------------------------------------------------')
# Out:
# Extraindo dados com Binary = False para Multinomial NB
# Tempo total esperado para execução do Multinomial NB é 90 seg
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Para modelo Multinomial NB:  alpha = 1.000000 accuracy = 0.780488
# Tempo total para treinar e prever o modelo Multinomial: 60.927679777145386
# --------------------------------------------------------------------------------------

# %% [markdown]
# ### Esta célula pode levar horas para ser executada!

# %%
# Multinomial Naive bayes: Alpha Vs accuracy 
acc = []
alp = []

for alpha in [float(j) / 100 for j in range(1, 101, 1)]:
    print ('--------------------------------------------------------------------------------------')
    ta = time()
    clf1 = MyMultinomialBayesClassifier(alpha)
    clf1.train(X_train,y_train)
    y_pred1 = clf1.predict(X_test)
    acc.append(np.mean((y_test-y_pred1)==0))
    alp.append(alpha)
    tb = time()
    print ("Tempo de Treinamento: " + str(tb-ta) + " acurácia, alpha é: " + str(np.mean((y_test-y_pred1)==0)) +","+str(alpha))
    #print ('alpha=%f accuracy = %f' %(alpha, np.mean((y_test-y_pred1)==0)))

# Plotting 
with PdfPages('multinomial.pdf') as pdf:
    pl.plot(alp,acc,marker = '.', linestyle = '-', color = 'r')
    pl.ylabel('Acurácia',color = 'g')
    pl.xlabel('Alpha',color = 'g')
    pl.title('Plot Alpha Vs Acurácia para Multinomial NB',color = 'r')
    pdf.savefig() 
    pl.close()

# Max Accuracy and Corresponding alpha.

print ("Acurácia máxima para o modelo Multinomial NB is: " + str(max(acc)))
print ("com valor correspondente alpha de:       " + str(alp[(acc.index(max(acc)))]))
# Out:
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 59.95912981033325 acurácia, alpha é: 0.7767923133776792,0.01
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 59.16617798805237 acurácia, alpha é: 0.7819660014781966,0.02
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 59.18854904174805 acurácia, alpha é: 0.7834441980783444,0.03
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 59.320066928863525 acurácia, alpha é: 0.7849223946784922,0.04
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.24576163291931 acurácia, alpha é: 0.7841832963784183,0.05
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.045060873031616 acurácia, alpha é: 0.7834441980783444,0.06
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.17740797996521 acurácia, alpha é: 0.7841832963784183,0.07
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.72975015640259 acurácia, alpha é: 0.7834441980783444,0.08
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.22172212600708 acurácia, alpha é: 0.7841832963784183,0.09
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.383121967315674 acurácia, alpha é: 0.7849223946784922,0.1
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.96800899505615 acurácia, alpha é: 0.78640059127864,0.11
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.69977807998657 acurácia, alpha é: 0.78640059127864,0.12
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.115941762924194 acurácia, alpha é: 0.78640059127864,0.13
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.41781401634216 acurácia, alpha é: 0.7878787878787878,0.14
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.70037508010864 acurácia, alpha é: 0.7886178861788617,0.15
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.42502307891846 acurácia, alpha é: 0.7878787878787878,0.16
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.68440890312195 acurácia, alpha é: 0.7878787878787878,0.17
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.03393793106079 acurácia, alpha é: 0.7893569844789357,0.18
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 59.797290086746216 acurácia, alpha é: 0.7893569844789357,0.19
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.93523192405701 acurácia, alpha é: 0.7893569844789357,0.2
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.058449268341064 acurácia, alpha é: 0.7893569844789357,0.21
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.61668562889099 acurácia, alpha é: 0.7886178861788617,0.22
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.873860120773315 acurácia, alpha é: 0.7886178861788617,0.23
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.4341721534729 acurácia, alpha é: 0.7886178861788617,0.24
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.87975096702576 acurácia, alpha é: 0.7893569844789357,0.25
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.63442015647888 acurácia, alpha é: 0.7886178861788617,0.26
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.601255893707275 acurácia, alpha é: 0.7871396895787139,0.27
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.30888819694519 acurácia, alpha é: 0.7871396895787139,0.28
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.80710506439209 acurácia, alpha é: 0.7878787878787878,0.29
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.24793791770935 acurácia, alpha é: 0.7878787878787878,0.3
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.308149099349976 acurácia, alpha é: 0.7871396895787139,0.31
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.991846799850464 acurácia, alpha é: 0.7856614929785661,0.32
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.05636787414551 acurácia, alpha é: 0.7856614929785661,0.33
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.00709891319275 acurácia, alpha é: 0.7871396895787139,0.34
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.425063371658325 acurácia, alpha é: 0.7871396895787139,0.35
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.223984241485596 acurácia, alpha é: 0.7871396895787139,0.36
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.1631920337677 acurácia, alpha é: 0.78640059127864,0.37
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.609041929244995 acurácia, alpha é: 0.7886178861788617,0.38
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.78523802757263 acurácia, alpha é: 0.7878787878787878,0.39
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.37405204772949 acurácia, alpha é: 0.7878787878787878,0.4
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.33150792121887 acurácia, alpha é: 0.7878787878787878,0.41
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 59.90048408508301 acurácia, alpha é: 0.7886178861788617,0.42
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.51352596282959 acurácia, alpha é: 0.7886178861788617,0.43
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.53474807739258 acurácia, alpha é: 0.7886178861788617,0.44
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.50558400154114 acurácia, alpha é: 0.7886178861788617,0.45
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.37843704223633 acurácia, alpha é: 0.7893569844789357,0.46
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.81666421890259 acurácia, alpha é: 0.7893569844789357,0.47
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.41523480415344 acurácia, alpha é: 0.7893569844789357,0.48
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.30624985694885 acurácia, alpha é: 0.7893569844789357,0.49
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.88466691970825 acurácia, alpha é: 0.7900960827790096,0.5
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.65273714065552 acurácia, alpha é: 0.7893569844789357,0.51
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.804986000061035 acurácia, alpha é: 0.7893569844789357,0.52
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.67499613761902 acurácia, alpha é: 0.7900960827790096,0.53
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.6408052444458 acurácia, alpha é: 0.7900960827790096,0.54
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.90186166763306 acurácia, alpha é: 0.7893569844789357,0.55
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.08891987800598 acurácia, alpha é: 0.7893569844789357,0.56
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.022419929504395 acurácia, alpha é: 0.7893569844789357,0.57
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.12749433517456 acurácia, alpha é: 0.7886178861788617,0.58
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.175657987594604 acurácia, alpha é: 0.7886178861788617,0.59
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.230822801589966 acurácia, alpha é: 0.7878787878787878,0.6
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.18487024307251 acurácia, alpha é: 0.7878787878787878,0.61
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.76041579246521 acurácia, alpha é: 0.7878787878787878,0.62
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.34985089302063 acurácia, alpha é: 0.7886178861788617,0.63
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.15953207015991 acurácia, alpha é: 0.7886178861788617,0.64
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.4411301612854 acurácia, alpha é: 0.7878787878787878,0.65
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.045753717422485 acurácia, alpha é: 0.7878787878787878,0.66
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 63.17051815986633 acurácia, alpha é: 0.7871396895787139,0.67
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.25773787498474 acurácia, alpha é: 0.7878787878787878,0.68
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.13651728630066 acurácia, alpha é: 0.7871396895787139,0.69
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.385359048843384 acurácia, alpha é: 0.7871396895787139,0.7
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.85215210914612 acurácia, alpha é: 0.7871396895787139,0.71
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.75608277320862 acurácia, alpha é: 0.78640059127864,0.72
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.58433294296265 acurácia, alpha é: 0.7856614929785661,0.73
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.628235816955566 acurácia, alpha é: 0.7856614929785661,0.74
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.72111678123474 acurácia, alpha é: 0.7856614929785661,0.75
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.86405825614929 acurácia, alpha é: 0.7849223946784922,0.76
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.92684006690979 acurácia, alpha é: 0.7849223946784922,0.77
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.0269820690155 acurácia, alpha é: 0.7841832963784183,0.78
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.54296398162842 acurácia, alpha é: 0.7841832963784183,0.79
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.65217208862305 acurácia, alpha é: 0.7841832963784183,0.8
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.48358201980591 acurácia, alpha é: 0.7834441980783444,0.81
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.30825185775757 acurácia, alpha é: 0.7834441980783444,0.82
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.94959306716919 acurácia, alpha é: 0.7834441980783444,0.83
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.41019415855408 acurácia, alpha é: 0.7827050997782705,0.84
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.55442404747009 acurácia, alpha é: 0.7819660014781966,0.85
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.60115718841553 acurácia, alpha é: 0.7812269031781227,0.86
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.492311000823975 acurácia, alpha é: 0.7812269031781227,0.87
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.573737144470215 acurácia, alpha é: 0.7812269031781227,0.88
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.789406061172485 acurácia, alpha é: 0.7812269031781227,0.89
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.974199056625366 acurácia, alpha é: 0.7812269031781227,0.9
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.19371581077576 acurácia, alpha é: 0.7812269031781227,0.91
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.5447678565979 acurácia, alpha é: 0.7812269031781227,0.92
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.36431312561035 acurácia, alpha é: 0.7812269031781227,0.93
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.13901996612549 acurácia, alpha é: 0.7804878048780488,0.94
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.79510998725891 acurácia, alpha é: 0.7804878048780488,0.95
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 63.58780026435852 acurácia, alpha é: 0.7804878048780488,0.96
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.82005310058594 acurácia, alpha é: 0.7804878048780488,0.97
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 61.79769206047058 acurácia, alpha é: 0.7804878048780488,0.98
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 62.463701009750366 acurácia, alpha é: 0.7804878048780488,0.99
# --------------------------------------------------------------------------------------
# Treinando Multinomial NB...
# Fazendo Previsões com Multinomial NB...
# Tempo de Treinamento: 60.71687293052673 acurácia, alpha é: 0.7804878048780488,1.0
# Acurácia máxima para o modelo Multinomial NB is: 0.7900960827790096
# com valor correspondente alpha de:       0.5

# %% [markdown]
# ### Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
